# %% [markdown]
# <a href="https://colab.research.google.com/github/intisar2024/master_ITM/blob/main/EJ08_STATEMENTS_pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working with Pandas library

# %%
import pandas as pd
from datetime import date
from datetime import datetime

# %% [markdown]
# Pass the following dictionary to Pandas dataframe:
#
# customer = {'id_customer': ['A100', 'B100', 'A200', 'C100'],
#             'ant_years': [3, 12, 1, 7],
#             'invoice': [30,25,51,29]
#             }

# %%
customer = {'id_customer': ['A100', 'B100', 'A200', 'C100'],
            'ant_years': [3, 12, 1, 7],
            'invoice': [30,25,51,29]
}

customer,type(customer)
# Out:
# ({'id_customer': ['A100', 'B100', 'A200', 'C100'],
#   'ant_years': [3, 12, 1, 7],
#   'invoice': [30, 25, 51, 29]},
#  dict)

# %% [markdown]
# Display the dataframe. Get the number of rows of the dataframe and the type of the fields.

# %%
customer = {'id_customer': ['A100', 'B100', 'A200', 'C100'],
            'ant_years': [3, 12, 1, 7],
            'invoice': [30,25,51,29]
}
df_customer=pd.DataFrame(customer)
df_customer
# Out:
#   id_customer  ant_years  invoice
# 0        A100          3       30
# 1        B100         12       25
# 2        A200          1       51
# 3        C100          7       29

# %% [markdown]
# Read the file __TOURIST.txt__ and pass it to a dataframe named __df_tur__.

# %%
from posixpath import sep
#/content/files /content/files
f=pd.read_csv("files//f_sales1.csv",
sep=';'  , header='infer')
f
# Out:
#       office salesperson product  units
# 0     Madrid       m_sp1      P1     20
# 1     Madrid       m_sp1      P2     19
# 2     Madrid       m_sp1      P3      8
# 3     Madrid       m_sp1      P4      5
# 4     Madrid       m_sp1      P5     18
# 5     Madrid       m_sp4     P14      1
# 6     Madrid       m_sp4     P15      7
# 7   Valencia       v_sp1     P10      1
# 8   Valencia       v_sp1     P11      2
# 9   Valencia       v_sp1     P12      0
# 10  Valencia       v_sp1     P13     19
# 11  Valencia       v_sp1     P14      2
# 12  Valencia       v_sp1     P15      6
# 13  Valencia       v_sp1     P16      4
# 14  Valencia       v_sp1     P17     15
# 15  Valencia       v_sp1     P18     10
# 16  Valencia       v_sp1     P19     18
# 17    Lisboa       l_sp1      P9     11
# 18    Lisboa       l_sp1     P10     10
# 19    Lisboa       l_sp1     P11     10
# 20    Lisboa       l_sp1     P12     16
# 21    Lisboa       l_sp1     P13     16
# ...

# %% [markdown]
# Check the types of the dataframe fields df_tur

# %% [markdown]
# Change the type of departure_date and arrival_date to datetime. Use astype method and type 'datetime64[ns]'.
# In an astype you must include the same types that appear in dtypes

# %% [markdown]
# Create a field called duration that calculates the days between the deparmture date and the arrival date.

# %% [markdown]
# Obtain a dataframe derived from df_tur having the first 10 rows and the columns: 'tourist_id' and 'origin'.

# %% [markdown]
# Obtain a dataframe derived from df_tur that is a 10-row sample and has only the date columns.

# %% [markdown]
# Obtener una muestra de 10 filas de df_tur con turistas procedentes de Asia

# %% [markdown]
# Obtain a sample of 10 rows of df_tur with tourists coming from Asia and spending more than 2000 euros.

# %% [markdown]
# Get the tourists who arrived in December 2018

# %% [markdown]
# Create a variable with the expense range according to the following criteria:
#
#     exp_range = 1    (0 - 500)
#     exp_range = 2    (500 - 1000)
#     exp_range = 3    (1000 - 1500)
#     exp_range = 4    (1500 - 2000)
#     exp_range = 5    (2000 -   )

# %% [markdown]
# Obtain the average value of expenditure and length of stay.

# %% [markdown]
# Obtain expenditure and average length of stay by origin

# %% [markdown]
# Export to csv the modified dataframe

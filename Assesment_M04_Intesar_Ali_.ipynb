# %% [markdown]
# <a href="https://colab.research.google.com/github/intisar2024/master_ITM/blob/main/Assesment_M04_Intesar_Ali_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assesment M04 - Data Visualization & Analytics

# %% [markdown]
# __Delivery__:
#
# * Deadline: 08/08/2024
# * send to: juavid01@ucm.es
# * name: assesment_m04_Intesar Ali Abdenabi.ipynb

# %%
import pandas as pd

# %% [markdown]
# __Create a dataframe__ using the data of the above cell. The name of the dataframe will be df_xyz, where xyz are the initials of the student name.   For example: student = 'Juan Vidal Gil' -> df_jvg

# %%
customers = {'customer_id': ['C01', 'C02', 'C03', 'C04', 'C05', 'C06', 'C07', 'C08', 'C09', 'C10'],
            'name': ['AJG', 'PMG', 'LUV', 'ZAM', 'MJA', 'ASB', 'LKM', 'ADF','JES', 'RCG'],
            'country': ['Spain', 'France', 'Libia', 'Portugal','France', 'Libia','Spain', 'France', 'Portugal', 'Spain' ],
             'contract_type': ['C1', 'C2', 'C3', 'C2', 'C3', 'C1','C3', 'C1', 'C2', 'C1'  ],
             'age': [33, 25, 44, 27, 51, 26, 62, 34, 19, 37 ],
             'invoice1': [100, 125, 144, 117, 91, 86, 82, 94, 119, 131 ],
             'invoice2': [103, 115, 111, 118, 98, 88, 88, 93, 109, 131 ],
             'invoice3': [90, 105, 131, 110, 95, 91, 79, 99, 112, 135 ]
            }
df_jvg = pd.DataFrame(customers)
df_jvg
# Out:
#   customer_id name   country contract_type  age  invoice1  invoice2  invoice3
# 0         C01  AJG     Spain            C1   33       100       103        90
# 1         C02  PMG    France            C2   25       125       115       105
# 2         C03  LUV     Libia            C3   44       144       111       131
# 3         C04  ZAM  Portugal            C2   27       117       118       110
# 4         C05  MJA    France            C3   51        91        98        95
# 5         C06  ASB     Libia            C1   26        86        88        91
# 6         C07  LKM     Spain            C3   62        82        88        79
# 7         C08  ADF    France            C1   34        94        93        99
# 8         C09  JES  Portugal            C2   19       119       109       112
# 9         C10  RCG     Spain            C1   37       131       131       135

# %%
customers = {'customer_id': ['C01', 'C02', 'C03', 'C04', 'C05', 'C06', 'C07', 'C08', 'C09', 'C10'],
            'name': ['AJG', 'PMG', 'LUV', 'ZAM', 'MJA', 'ASB', 'LKM', 'ADF','JES', 'RCG'],
            'country': ['Spain', 'France', 'Libia', 'Portugal','France', 'Libia','Spain', 'France', 'Portugal', 'Spain' ],
             'contract_type': ['C1', 'C2', 'C3', 'C2', 'C3', 'C1','C3', 'C1', 'C2', 'C1'  ],
             'age': [33, 25, 44, 27, 51, 26, 62, 34, 19, 37 ],
             'invoice1': [100, 125, 144, 117, 91, 86, 82, 94, 119, 131 ],
             'invoice2': [103, 115, 111, 118, 98, 88, 88, 93, 109, 131 ],
             'invoice3': [90, 105, 131, 110, 95, 91, 79, 99, 112, 135 ]
            }
df_IAA = pd.DataFrame(customers)
df_IAA
# Out:
#   customer_id name   country contract_type  age  invoice1  invoice2  invoice3
# 0         C01  AJG     Spain            C1   33       100       103        90
# 1         C02  PMG    France            C2   25       125       115       105
# 2         C03  LUV     Libia            C3   44       144       111       131
# 3         C04  ZAM  Portugal            C2   27       117       118       110
# 4         C05  MJA    France            C3   51        91        98        95
# 5         C06  ASB     Libia            C1   26        86        88        91
# 6         C07  LKM     Spain            C3   62        82        88        79
# 7         C08  ADF    France            C1   34        94        93        99
# 8         C09  JES  Portugal            C2   19       119       109       112
# 9         C10  RCG     Spain            C1   37       131       131       135

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1)Create a new __calculated field__ on df_xyz. The calculated field will be obtained based on a formula or expression __chosen by the student__ (each student must choose his or her formula). The name of the new field will be f_xyz (where xyz are the initials of the student name)

# %%
df_jvg['f_jvg'] = 2*df_jvg['invoice1'] + df_jvg['invoice2'] - df_jvg['invoice3']
df_jvg
# Out:
#   customer_id name   country contract_type  age  invoice1  invoice2  invoice3  \
# 0         C01  AJG     Spain            C1   33       100       103        90
# 1         C02  PMG    France            C2   25       125       115       105
# 2         C03  LUV     Libia            C3   44       144       111       131
# 3         C04  ZAM  Portugal            C2   27       117       118       110
# 4         C05  MJA    France            C3   51        91        98        95
# 5         C06  ASB     Libia            C1   26        86        88        91
# 6         C07  LKM     Spain            C3   62        82        88        79
# 7         C08  ADF    France            C1   34        94        93        99
# 8         C09  JES  Portugal            C2   19       119       109       112
# 9         C10  RCG     Spain            C1   37       131       131       135
#
#    f_jvg
# 0    213
# 1    260
# 2    268
# 3    242
# 4    185
# 5    169
# 6    173
# 7    182
# 8    235
# 9    258

# %%
df_IAA=df_IAA.assign(f_IAA=df_IAA['invoice1']+df_IAA['invoice2']+df_IAA['invoice3'])
df_IAA
# Out:
#   customer_id name   country contract_type  age  invoice1  invoice2  invoice3  \
# 0         C01  AJG     Spain            C1   33       100       103        90
# 1         C02  PMG    France            C2   25       125       115       105
# 2         C03  LUV     Libia            C3   44       144       111       131
# 3         C04  ZAM  Portugal            C2   27       117       118       110
# 4         C05  MJA    France            C3   51        91        98        95
# 5         C06  ASB     Libia            C1   26        86        88        91
# 6         C07  LKM     Spain            C3   62        82        88        79
# 7         C08  ADF    France            C1   34        94        93        99
# 8         C09  JES  Portugal            C2   19       119       109       112
# 9         C10  RCG     Spain            C1   37       131       131       135
#
#    f_IAA
# 0    293
# 1    345
# 2    386
# 3    345
# 4    284
# 5    265
# 6    249
# 7    286
# 8    340
# 9    397

# %%
df_IAA['f_IAA']=df_IAA['invoice1']+df_IAA['invoice2']+df_IAA['invoice3']
df_IAA
# Out:
#   customer_id name   country contract_type  age  invoice1  invoice2  invoice3  \
# 0         C01  AJG     Spain            C1   33       100       103        90
# 1         C02  PMG    France            C2   25       125       115       105
# 2         C03  LUV     Libia            C3   44       144       111       131
# 3         C04  ZAM  Portugal            C2   27       117       118       110
# 4         C05  MJA    France            C3   51        91        98        95
# 5         C06  ASB     Libia            C1   26        86        88        91
# 6         C07  LKM     Spain            C3   62        82        88        79
# 7         C08  ADF    France            C1   34        94        93        99
# 8         C09  JES  Portugal            C2   19       119       109       112
# 9         C10  RCG     Spain            C1   37       131       131       135
#
#    f_IAA
# 0    293
# 1    345
# 2    386
# 3    345
# 4    284
# 5    265
# 6    249
# 7    286
# 8    340
# 9    397

# %% [markdown]
# 2)Perform a __filtering operation__ on df_xyz to obtain a second dataframe called df_xyz2. __The student will choose the filtering operation__ he considers most appropriate based on the data

# %% [markdown]
# # **It has been answered in several ways.**

# %%
df_IAA=pd.DataFrame(customers)
df_IAA
df_IAA2=df_IAA[(df_IAA['age'] >=26) & (df_IAA['contract_type']=='C1')]
df_IAA2
# Out:
#   customer_id name country contract_type  age  invoice1  invoice2  invoice3
# 0         C01  AJG   Spain            C1   33       100       103        90
# 5         C06  ASB   Libia            C1   26        86        88        91
# 7         C08  ADF  France            C1   34        94        93        99
# 9         C10  RCG   Spain            C1   37       131       131       135

# %%
df_IAA2=df_IAA[(df_IAA['country']=='Libia') & (df_IAA['invoice3']>=91)]
#print(df_xyz2)
df_IAA2
# Out:
#   customer_id name country contract_type  age  invoice1  invoice2  invoice3
# 2         C03  LUV   Libia            C3   44       144       111       131
# 5         C06  ASB   Libia            C1   26        86        88        91

# %%
df_IAA2=df_IAA[(df_IAA['country']).isin(['Libia','Spain']) & (df_IAA['age'] >=26)]
#print(df_xyz2)
df_IAA2
# Out:
#   customer_id name country contract_type  age  invoice1  invoice2  invoice3
# 0         C01  AJG   Spain            C1   33       100       103        90
# 2         C03  LUV   Libia            C3   44       144       111       131
# 5         C06  ASB   Libia            C1   26        86        88        91
# 6         C07  LKM   Spain            C3   62        82        88        79
# 9         C10  RCG   Spain            C1   37       131       131       135

# %%
df_jvg2 = df_jvg[(df_jvg['contract_type']=='C1') & (df_jvg['country']=='Spain')]
df_jvg2
# Out:
#   customer_id name country contract_type  age  invoice1  invoice2  invoice3
# 0         C01  AJG   Spain            C1   33       100       103        90
# 9         C10  RCG   Spain            C1   37       131       131       135

# %% [markdown]
# 3)__Perform an aggregation operation__ using contract_type as grouping field.Perform an aggregation operation over the f_xyz field. The student will choose the aggregation operation (count(), sum(), mean(), etc.). The name of the new calculated field (result of the aggregation) will be a_xyz

# %%
df_jvg.groupby('contract_type').agg(a_jvg=('age', 'mean'))
# Out:
#                    a_jvg
# contract_type
# C1             32.500000
# C2             23.666667
# C3             52.333333

# %% [markdown]
# # **It has been answered in several ways.**

# %%
df_IAA.groupby('contract_type').agg(a_IAA=('invoice1','sum'))
# Out:
#                a_IAA
# contract_type
# C1               411
# C2               361
# C3               317

# %%
df_IAA.groupby('contract_type').agg(a_IAA=('invoice1','count'))
# Out:
#                a_IAA
# contract_type
# C1                 4
# C2                 3
# C3                 3

# %%
df_IAA.groupby('contract_type').agg(a_IAA=('invoice1','mean'))
# Out:
#                     a_IAA
# contract_type
# C1             102.750000
# C2             120.333333
# C3             105.666667

# %%
df_IAA[df_IAA['invoice1'] >= 82].groupby('contract_type').agg(invoice_mean=('invoice1','mean'),
                      invoice_sum=('invoice1', 'sum'),
                      customer_num=('invoice1','count')
                          )
# Out:
#                invoice_mean  invoice_sum  customer_num
# contract_type
# C1               102.750000          411             4
# C2               120.333333          361             3
# C3               105.666667          317             3

# %% [markdown]
# 4)__Obtain a bar chart__ bar chart showing the number of customers for each country. The student can add to the graph the elements he/she considers useful (title, name of axes, legend, etc.), the The bar chart may be horizontal or vertical.
# __Optional:__ Obtain the same, but using a pie chart with the options the students considers useful

# %%
df_jvg['country'].value_counts().plot(kind='bar',
                                grid=True,
                                xlabel='country',
                                ylabel='number of customers')
# Out:
# <Axes: xlabel='country', ylabel='number of customers'>

# %%
df_IAA['country'].value_counts().plot(kind='barh',
                                grid=True,
                                title='The number of customers around some countries',
                               color=['red','blue','green','gold'],
                                ylabel='countries',
                                xlabel='number of customers')
# Out:
# <Axes: title={'center': 'The number of customers around some countries'}, xlabel='number of customers', ylabel='countries'>

# %%
df_IAA['country'].value_counts().plot(kind='pie',
                                      autopct='%.2f%%',
                                      colormap='summer',
                                grid=True)
                                #xlabel='country',
                               # ylabel='number of customers')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# 5)__Export__ the dataframe to a csv file. The name of the file will be: export_xyz.csv
# __Optional:__ export the dataframe to any other file format

# %%
df_jvg.to_csv("export_jvg.csv", index=False)

# %%
df_IAA.to_csv("f_sales1.txt" ,index=False )

# %%
df_IAA.to_csv("intesar.xlsx" ,index=False )

# %% [markdown]
# __Optional step:__ (not mandatory)
#
# Perform an __additional step__ on the dataframe df_xyz. It is important that this additional step is chosen by each student (avoid performing the same steps as classmates, that it is original or that it has some difference).

# %% [markdown]
# ### **`### How to arrange the table in ascending order by age `**

# %%
df_IAA_sorted=df_IAA.sort_values(by='age')
df_IAA_sorted
# Out:
#   customer_id name   country contract_type  age  invoice1  invoice2  invoice3
# 8         C09  JES  Portugal            C2   19       119       109       112
# 1         C02  PMG    France            C2   25       125       115       105
# 5         C06  ASB     Libia            C1   26        86        88        91
# 3         C04  ZAM  Portugal            C2   27       117       118       110
# 0         C01  AJG     Spain            C1   33       100       103        90
# 7         C08  ADF    France            C1   34        94        93        99
# 9         C10  RCG     Spain            C1   37       131       131       135
# 2         C03  LUV     Libia            C3   44       144       111       131
# 4         C05  MJA    France            C3   51        91        98        95
# 6         C07  LKM     Spain            C3   62        82        88        79

# %% [markdown]
# ### **`how to arrange the tableframe in descending order by age `**

# %%
df_IAA_sorted=df_IAA.sort_values(by='age', ascending=False)
df_IAA_sorted
# Out:
#   customer_id name   country contract_type  age  invoice1  invoice2  invoice3
# 6         C07  LKM     Spain            C3   62        82        88        79
# 4         C05  MJA    France            C3   51        91        98        95
# 2         C03  LUV     Libia            C3   44       144       111       131
# 9         C10  RCG     Spain            C1   37       131       131       135
# 7         C08  ADF    France            C1   34        94        93        99
# 0         C01  AJG     Spain            C1   33       100       103        90
# 3         C04  ZAM  Portugal            C2   27       117       118       110
# 5         C06  ASB     Libia            C1   26        86        88        91
# 1         C02  PMG    France            C2   25       125       115       105
# 8         C09  JES  Portugal            C2   19       119       109       112

# %% [markdown]
# # **how to arrange the tableframe in scending order by (contract_type)**

# %%
df_IAA_sorted=df_IAA.sort_values(by='contract_type')
df_IAA_sorted
# Out:
#   customer_id name   country contract_type  age  invoice1  invoice2  invoice3
# 0         C01  AJG     Spain            C1   33       100       103        90
# 5         C06  ASB     Libia            C1   26        86        88        91
# 7         C08  ADF    France            C1   34        94        93        99
# 9         C10  RCG     Spain            C1   37       131       131       135
# 1         C02  PMG    France            C2   25       125       115       105
# 3         C04  ZAM  Portugal            C2   27       117       118       110
# 8         C09  JES  Portugal            C2   19       119       109       112
# 2         C03  LUV     Libia            C3   44       144       111       131
# 4         C05  MJA    France            C3   51        91        98        95
# 6         C07  LKM     Spain            C3   62        82        88        79

# %% [markdown]
# # **choose four rows at random**

# %%
sampled_df=df_IAA.sample(n=4)
sampled_df
# Out:
#   customer_id name   country contract_type  age  invoice1  invoice2  invoice3
# 3         C04  ZAM  Portugal            C2   27       117       118       110
# 1         C02  PMG    France            C2   25       125       115       105
# 8         C09  JES  Portugal            C2   19       119       109       112
# 5         C06  ASB     Libia            C1   26        86        88        91

# %%
df_IAA.dtypes
# Out:
# customer_id      object
# name             object
# country          object
# contract_type    object
# age               int64
# invoice1          int64
# invoice2          int64
# invoice3          int64
# dtype: object

# %% [markdown]
# # **We check for null in all columns**

# %%
df_IAA.isnull().sum()
# Out:
# customer_id      0
# name             0
# country          0
# contract_type    0
# age              0
# invoice1         0
# invoice2         0
# invoice3         0
# dtype: int64

# %% [markdown]
# # **file size**

# %%
df_IAA.shape
# Out:
# (10, 8)

# %% [markdown]
# **We check that there are no duplicates.**

# %%
df_IAA.duplicated(subset='customer_id').sum()
# Out:
# 0

# %% [markdown]
# # **copy a dataframe to another datafram**

# %%
df_IAA1 = df_IAA.copy()
df_IAA1.head(2)
# Out:
#   customer_id name country contract_type  age  invoice1  invoice2  invoice3
# 0         C01  AJG   Spain            C1   33       100       103        90
# 1         C02  PMG  France            C2   25       125       115       105
